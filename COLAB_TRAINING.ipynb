# %% [markdown]
# # AI Talent Intelligence - Model Training (Google Colab)
#
# This notebook trains ML models for resume analysis using GPU.
# **Runtime: Use GPU (Runtime > Change runtime type > GPU)**

# %%
# Clone the project from GitHub (or use your own repo)
# !git clone https://github.com/your-repo/AI-Talent-Intelligence-Platform.git
import os
os.chdir('AI-Talent-Intelligence-Platform')
print("Project cloned!")

# %%
# Alternative: Upload required files directly (if not using git)
# Run this cell and select files to upload
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')

# %%
# Install PyTorch with CUDA (for GPU)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 -q

# Install other dependencies
# !pip install sentence-transformers scikit-learn pandas numpy joblib xgboost lightgbm django psycopg2-binary openai pymupdf4llm python-dotenv djangorestframework django-cors-headers -q

print("Dependencies installed!")

# %%
# Verify GPU
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# Set environment
import os
os.environ['PYTHONPATH'] = '/content/AI-Talent-Intelligence-Platform/django_pg_backend/core'
os.chdir('/content/AI-Talent-Intelligence-Platform/django_pg_backend/core')
print("Working directory:", os.getcwd())

# %%
# Run training
# !python manage.py train_models_v2

# %%
# Download trained models
import shutil
from google.colab import files

# Zip the trained models folder
shutil.make_archive('/content/trained_models', 'zip', 
                    '/content/AI-Talent-Intelligence-Platform/django_pg_backend/core/apps/analytics/management/trained_models')

# Download
files.download('/content/trained_models.zip')
print("Download complete!")
